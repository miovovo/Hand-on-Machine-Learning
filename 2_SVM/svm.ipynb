# %% [markdown]
# 分别使用三种损失函数
#
# 实现佩加索斯（Pegasos）算法
#
# 在给定的数据集上进行训练与测试

# %% [markdown]
# ![{DB8ECCF4-C3D5-4DD5-B98F-BE4C7F25C933}.png](attachment:{DB8ECCF4-C3D5-4DD5-B98F-BE4C7F25C933}.png)

# %% [markdown]
# 之前课上讲过软-SVM，我们要实现的佩加索斯算法就是软-SVM
#
# 这里是它的目标函数，我们希望找到一组w和b，让目标函数最小
#
# 其中C是参数，l是损失函数，但这个损失函数不方便求梯度，于是就有了三种替代损失

# %% [markdown]
# https://blog.csdn.net/sdu_hao/article/details/84189266

# %%
import numpy as np
np.exp(2)
# Out:
# 7.38905609893065

# %% [markdown]
# --C=0.001 --T=5000
#
# acc = 81.6%

# %% [markdown]
# ![{DCF50087-4DB4-4AE4-A8E0-14D03453FF37}.png](attachment:{DCF50087-4DB4-4AE4-A8E0-14D03453FF37}.png)

# %% [markdown]
# ![{7292D9E9-DD4C-4962-BD9B-2C756BD8DBBE}.png](attachment:{7292D9E9-DD4C-4962-BD9B-2C756BD8DBBE}.png)

# %%
if decay=='time_rev':
        return eta_initial/(1+decay_rate*t)
    elif decay=='exp':
        return eta_initial*np.exp(-decay_rate*t)
